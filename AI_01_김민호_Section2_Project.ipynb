# %% [markdown]
# # 프로젝트 주제 : 서울시 아파트 가격 예측
#
# * 서울특별시 부동산 실거래가 정보
#     - http://data.seoul.go.kr/dataList/OA-15548/S/1/datasetView.do
#
#   ![image.png](attachment:image.png)
#
# ```
# 프로젝트 목적 : 서울시에서 제공하는 최근 10년간의 실거래 데이터를 가지고 2020, 2021년 집 값을 예측하는 프로젝트
# ```
# ```
# 2020년 서울에 부동산 시장은 정부의 규제와 투기 등 여러가지 요인으로 인해 변동성이 컸습니다. 물론 이 데이터 만으로 집 값을 정확하게 예측 하는 것은 불가능합니다. 앞서 말한 정뷰의 규제와 같이 예상하지 못한 일도 나타날 수 있기 때문입니다. 그러므로 이런 정부 규제나 외적인 부분이 영향을 주는 것은 배제하고 프로젝트를 진행 할 것입니다.
#
# 집값을 결정하는 특성들은 여러가지가 있습니다. 흔히 말하는 역세권으로 지하철역에 가까운경우 아파트 시세가 올라가거나, 건물이 최신에 지어 졌는지에 따라서도 아파트 가격에 영향을 미칠 것입니다. 이와 같이 많은 이유가 있을텐데 집 값의 영향을 미치는 것이 무엇인지도 파악 해볼 것입니다.
#
# 또한 서울시에 자치구 별, 년도 별로 집값이 어떻게 변화를 했는지도 알아 볼 예정입니다.
#
# 우리가 예측 하려는 특징과 목표를 모두 가지고 있기 때문에 supervised 러닝을 할 것이다. 또한 target인 집값이 연속적이기 때문에 회귀 모델로 만들 것입니다.
#
# ```

# %% [markdown]
# ## 2020, 2021년의 집 값을 얼마나 잘 예측 할 것인가?
#
# ## 서울시 아파트 값의 영향을 미치는 특성은 무엇인가?

# %% [markdown]
# # EDA 데이터 탐색

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')
plt.rc('axes', unicode_minus=False)

# %%
raw_df_2019 = pd.read_csv('./서울특별시 부동산 실거래가 정보.csv', low_memory= False, encoding="cp949")

raw_df_2019.head()
# Out:
#                   실거래가아이디                 지번코드  시군구코드  자치구명       법정동코드  법정동명  \
# 0  11305-2021-4-0000633-1  1130510200102420000  11305   강북구  1130510200    번동
# 1  11110-2021-4-0000400-1  1111018300102930001  11110   종로구  1111018300   평창동
# 2  11305-2021-4-0000907-1           1130510100  11305   강북구  1130510100   미아동
# 3  11410-2021-4-0001112-1           1141011000  11410  서대문구  1141011000  북아현동
# 4  11305-2021-4-0000824-1  1130510100102280024  11305   강북구  1130510100   미아동
#
#    신고년도  업무구분코드 업무구분  물건번호   대지권면적    건물면적 관리구분코드  층정보  건물주용도코드 건물주용도  \
# 0  2021       4   신고     1     NaN   49.94      0  7.0     2001   아파트
# 1  2021       4   신고     1   54.22   76.56      0  1.0     2002  연립주택
# 2  2021       4   신고     1  109.00  170.97      0  NaN     1001  단독주택
# 3  2021       4   신고     1   66.00  118.80      0  NaN     1001  단독주택
# 4  2021       4   신고     1   25.32   49.22      0  4.0     2002  연립주택
#
#          물건금액     건물명    건축년도
# 0   563000000   주공1단지  1991.0
# 1   360000000     천지인  2003.0
# 2   405000000     NaN  1991.0
# 3  1272220000     NaN  1992.0
# 4   180000000  현대아트빌라  1995.0

# %%
raw_df_2019.shape
# Out:
# (2282346, 19)

# %%
train = raw_df_2019[(raw_df_2019['신고년도'] < 2020) & (raw_df_2019['신고년도'] > 2009)]

test = raw_df_2019[(raw_df_2019['신고년도'] >= 2020)]

train.shape, test.shape
# Out:
# ((1441702, 19), (196705, 19))

# %% [markdown]
# **컬럼 이름이 한글이므로 영어로 변경**

# %%
train = train.rename({'실거래가아이디': 'RTMS_ID','지번코드': 'LAND_CD', '시군구코드':'SGG_CD', '자치구명':'SGG_NM',
                       '법정동코드':'BJDONG10_CD', '법정동명': 'BJDONG_NM', '신고년도': 'ACC_YEAR', '업무구분코드':'JOB_GBN',
                        '업무구분' : 'JOB_GBN_NM', '물건번호':'OBJ_SEQNO','대지권면적':'TOT_AREA','건물면적':'BLDG_AREA',
                       '관리구분코드':'RIGHT_GBN','층정보':'FLR_INFO', '건물주용도코드':'BLDG_MUSE_CD', '건물주용도':'BLDG_MUSE_NM','물건금액' : 'OBJ_AMT',
                       '건축년도':'BUILD_YEAR', '건물명':'BLDG_NM'}, axis='columns')

test = test.rename({'실거래가아이디': 'RTMS_ID','지번코드': 'LAND_CD', '시군구코드':'SGG_CD', '자치구명':'SGG_NM',
                       '법정동코드':'BJDONG10_CD', '법정동명': 'BJDONG_NM', '신고년도': 'ACC_YEAR', '업무구분코드':'JOB_GBN',
                        '업무구분' : 'JOB_GBN_NM', '물건번호':'OBJ_SEQNO','대지권면적':'TOT_AREA','건물면적':'BLDG_AREA',
                       '관리구분코드':'RIGHT_GBN','층정보':'FLR_INFO', '건물주용도코드':'BLDG_MUSE_CD', '건물주용도':'BLDG_MUSE_NM','물건금액' : 'OBJ_AMT',
                       '건축년도':'BUILD_YEAR', '건물명':'BLDG_NM'}, axis='columns')

# %%
# 검증 셋의 경우 2020 데이터 검증 셋으로 설정
val = train[train['ACC_YEAR'] >= 2019]
train = train[train['ACC_YEAR'] < 2019]

# %%
train.shape, val.shape, test.shape
# Out:
# ((1311440, 19), (130262, 19), (196705, 19))

# %%
train.head()
# Out:
#                        RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326967  11380-2018-4-0010781-1  1138010400104460011   11380    은평구
# 326968  11545-2018-4-0005964-1  1154510200103800014   11545    금천구
# 326969  11380-2018-4-0010780-1  1138010200101410111   11380    은평구
# 326970  11230-2018-4-0009724-1  1123010600103360000   11230   동대문구
# 326971  11380-2018-4-0010779-1  1138010300102300003   11380    은평구
#
#         BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326967   1138010400       갈현동      2018        4         신고          1
# 326968   1154510200       독산동      2018        4         신고          1
# 326969   1138010200       녹번동      2018        4         신고          1
# 326970   1123010600       장안동      2018        4         신고          1
# 326971   1138010300       불광동      2018        4         신고          1
#
#         TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326967     23.61      31.06         0       1.0          2002         연립주택
# 326968     28.67      48.54         0       3.0          2002         연립주택
# 326969     21.22      31.56         0      -1.0          2002         연립주택
# 326970       NaN      84.87         0      11.0          2001          아파트
# 326971       NaN      56.40         0       8.0          2001          아파트
#
#           OBJ_AMT        BLDG_NM  BUILD_YEAR
# 326967   80000000       (446-11)      1987.0
# 326968  180000000   금호타운(380-14)      2001.0
# 326969   67000000  신진빌라(141-111)      1991.0
# 326970  600000000   장안현대홈타운(336)      2003.0
# 326971  285900000          대암아파트      1997.0

# %% [markdown]
# 'RTMS_ID(실거래가아이디)'가 SGG_CD(시군구코드) + ACC_YEAR(신고년도) + JOB_GBN(업무구분코드) + 고유번호의 조합으로 되어 있습니다.
#
# LAND_CD(지번코드)의 앞 10자리는 BJDONG10_CD 가 포함되어 있습니다.
#
# BJDONG10_CD(법정동코드) 는 SGG_CD(시군구코드) + 해당 동 코드 고유 번호

# %%
train.describe()
# Out:
#              SGG_CD   BJDONG10_CD      ACC_YEAR       JOB_GBN     OBJ_SEQNO  \
# count  1.311440e+06  1.311440e+06  1.311440e+06  1.311440e+06  1.311440e+06
# mean   1.145210e+04  1.145222e+09  2.014670e+03  4.086028e+00  1.315484e+00
# std    1.741543e+02  1.741492e+07  2.428373e+00  6.501826e-01  3.270288e+00
# min    1.111000e+04  1.111010e+09  2.010000e+03  4.000000e+00  0.000000e+00
# 25%    1.130500e+04  1.130510e+09  2.013000e+03  4.000000e+00  1.000000e+00
# 50%    1.144000e+04  1.144013e+09  2.015000e+03  4.000000e+00  1.000000e+00
# 75%    1.159000e+04  1.159011e+09  2.017000e+03  4.000000e+00  1.000000e+00
# max    1.174000e+04  1.174011e+09  2.018000e+03  9.000000e+00  2.490000e+02
#
#            TOT_AREA     BLDG_AREA      FLR_INFO  BLDG_MUSE_CD       OBJ_AMT  \
# count  5.995220e+05  1.311440e+06  1.205677e+06  1.311440e+06  1.311440e+06
# mean   3.041929e+03  7.619630e+01  7.100971e+00  2.802096e+03  4.376161e+08
# std    1.157522e+06  5.530150e+01  5.935992e+00  3.192761e+03  3.879380e+08
# min    0.000000e+00  3.310000e+00 -4.000000e+00  1.001000e+03  3.500000e+06
# 25%    2.321000e+01  4.794000e+01  3.000000e+00  2.001000e+03  2.090000e+08
# 50%    3.246000e+01  6.096000e+01  5.000000e+00  2.001000e+03  3.350000e+08
# 75%    5.534000e+01  8.494000e+01  1.000000e+01  2.002000e+03  5.350000e+08
# max    4.481289e+08  3.619840e+03  9.000000e+01  1.420200e+04  2.917370e+10
#
#          BUILD_YEAR
# count  1.307573e+06
# mean   1.932678e+03
# std    3.570130e+02
# min    0.000000e+00
# 25%    1.991000e+03
# 50%    2.000000e+03
# 75%    2.006000e+03
# max    2.019000e+03

# %% [markdown]
# 위에 데이터를 보면 **대지권면적, 건축년도 0.0**은 기입을 안한 결측치로 판단, 층 정보의 최소값이 -4인 값도 있다. 지하층이 있을 수도 있다는 추측을 해볼 수 있습니다.

# %% [markdown]
# ## 서울시가 제공하는 특성들은 서로 얼마나 연관이 되어 있을까?

# %%
corr=train.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=.8, linewidths=0.01,
            square=True,annot=True,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %% [markdown]
# OBJ_AMT(집 값)과의 연관성이 가장큰 Feature는 BLDG_AREA와 연관이 높은 것을 볼 수 있습니다. 회귀문제에서 다중공산성을 잘 처리하는 것이 중요한데 Feature Engeneering을 통해 관련 특성들을 제거 해야 한다.
#
# *다중공산성 : 독립변수들 간에 강한 상관관계가 나타나는 문제*

# %%
train['SGDONG_NM'] = train[['SGG_NM', 'BJDONG_NM']].apply(lambda x: ' '.join(x), axis=1)
val['SGDONG_NM'] = val[['SGG_NM', 'BJDONG_NM']].apply(lambda x: ' '.join(x), axis=1)
test['SGDONG_NM'] = test[['SGG_NM', 'BJDONG_NM']].apply(lambda x: ' '.join(x), axis=1)

# %%
train.head()
# Out:
#                        RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326967  11380-2018-4-0010781-1  1138010400104460011   11380    은평구
# 326968  11545-2018-4-0005964-1  1154510200103800014   11545    금천구
# 326969  11380-2018-4-0010780-1  1138010200101410111   11380    은평구
# 326970  11230-2018-4-0009724-1  1123010600103360000   11230   동대문구
# 326971  11380-2018-4-0010779-1  1138010300102300003   11380    은평구
#
#         BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326967   1138010400       갈현동      2018        4         신고          1
# 326968   1154510200       독산동      2018        4         신고          1
# 326969   1138010200       녹번동      2018        4         신고          1
# 326970   1123010600       장안동      2018        4         신고          1
# 326971   1138010300       불광동      2018        4         신고          1
#
#         TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326967     23.61      31.06         0       1.0          2002         연립주택
# 326968     28.67      48.54         0       3.0          2002         연립주택
# 326969     21.22      31.56         0      -1.0          2002         연립주택
# 326970       NaN      84.87         0      11.0          2001          아파트
# 326971       NaN      56.40         0       8.0          2001          아파트
#
#           OBJ_AMT        BLDG_NM  BUILD_YEAR SGDONG_NM
# 326967   80000000       (446-11)      1987.0   은평구 갈현동
# 326968  180000000   금호타운(380-14)      2001.0   금천구 독산동
# 326969   67000000  신진빌라(141-111)      1991.0   은평구 녹번동
# 326970  600000000   장안현대홈타운(336)      2003.0  동대문구 장안동
# 326971  285900000          대암아파트      1997.0   은평구 불광동

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings

warnings.filterwarnings(action='ignore') 


# %matplotlib inline

if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# 범주형의 카디널리티를 확인

# %%
train.nunique()
# Out:
# RTMS_ID         1311440
# LAND_CD           81428
# SGG_CD               25
# SGG_NM               25
# BJDONG10_CD         429
# BJDONG_NM           427
# ACC_YEAR              9
# JOB_GBN               2
# JOB_GBN_NM            2
# OBJ_SEQNO           221
# TOT_AREA          13733
# BLDG_AREA         34383
# RIGHT_GBN             5
# FLR_INFO             79
# BLDG_MUSE_CD          4
# BLDG_MUSE_NM          4
# OBJ_AMT           34125
# BLDG_NM           62479
# BUILD_YEAR          113
# SGDONG_NM           429
# dtype: int64

# %%
[(x, train[x].unique()) for x in train.columns if train[x].dtypes == object]
# Out:
# [('RTMS_ID',
#   array(['11380-2018-4-0010781-1', '11545-2018-4-0005964-1',
#          '11380-2018-4-0010780-1', ..., '11470-2010-4-0002609-1',
#          '11470-2010-4-0002607-1', '11470-2010-4-0002610-1'], dtype=object)),
#  ('LAND_CD',
#   array(['1138010400104460011', '1154510200103800014',
#          '1138010200101410111', ..., '1147010200105570049',
#          '1147010100101280096', '1147010300101400014'], dtype=object)),
#  ('SGG_NM',
#   array(['은평구', '금천구', '동대문구', '동작구', '강서구', '송파구', '강남구', '광진구', '서초구',
#          '중구', '중랑구', '종로구', '구로구', '관악구', '용산구', '성동구', '도봉구', '노원구',
#          '강동구', '성북구', '양천구', '영등포구', '마포구', '강북구', '서대문구'], dtype=object)),
#  ('BJDONG_NM',
#   array(['갈현동', '독산동', '녹번동', '장안동', '불광동', '흑석동', '수색동', '제기동', '대조동',
#          '휘경동', '사당동', '진관동', '청량리동', '상도동', '응암동', '용두동', '등촌동', '대방동',
#          '신사동', '답십리동', '역촌동', '증산동', '오금동', '이문동', '전농동', '청담동', '자양동',
#          '화곡동', '서초동', '세곡동', '방화동', '방배동', '역삼동', '광장동', '염창동', '양재동',
#          '구산동', '구의동', '도곡동', '내발산동', '삼성동', '가양동', '잠원동', '중곡동', '수서동',
#          '반포동', '회기동', '논현동', '의주로1가', '압구정동', '개포동', '우면동', '대치동', '내곡동',
#          '신내동', '율현동', '마곡동', '자곡동', '화양동', '평창동', '숭인동', '동숭동', '창신동',
#          '신대방동', '명륜1가', '익선동', '구기동', '내수동', '무악동', '공항동', '혜화동', '홍지동',
#          '명륜2가', '군자동', '사직동', '원서동', '연지동', '가회동', '능동', '일원동', '신영동',
#          '부암동', '노량진동', '수송동', '안국동', '체부동', '신설동', '필운동', '운니동', '명륜3가',
#          '누상동', '효제동', '신문로2가', '청운동', '경운동', '홍파동', '창성동', '충신동', '소격동',
#          '관철동', '인사동', '이화동', '연건동', '신문로1가', '신교동', '항동', '교북동', '적선동',
#          '인의동', '교남동', '계동', '견지동', '효자동', '종로1가', '행촌동', '종로5가', '옥인동',
#          '삼청동', '사간동', '평동', '봉천동', '명륜4가', '누하동', '당주동', '동자동', '금호동4가',
#          '금호동3가', '옥수동', '신당동', '도선동', '용답동', '보광동', '송정동', '성수동1가',
#          '금호동1가', '중림동', '서빙고동', '응봉동', '신창동', '흥인동', '개화동', '순화동', '성수동2가',
#          '광희동1가', '신림동', '팔판동', '종로6가', '돈의동', '낙원동', '재동', '통인동', '통의동',
#          '원남동', '면목동', '중화동', '외발산동', '창동', '도봉동', '쌍문동', '공릉동', '문정동',
#          '월계동', '중계동', '상계동', '암사동', '풍납동', '묵동', '장위동', '종암동', '정릉동',
#          '삼선동2가', '하계동', '동선동2가', '돈암동', '동소문동7가', '석관동', '하월곡동', '신월동',
#          '상일동', '성북동', '용산동5가', '천호동', '길음동', '안암동2가', '상월곡동', '신정동', '한남동',
#          '안암동5가', '이촌동', '효창동', '보문동6가', '한강로2가', '안암동3가', '삼선동1가', '이태원동',
#          '후암동', '목동', '동빙고동', '한강로3가', '원효로3가', '용문동', '신계동', '서계동', '도원동',
#          '원효로2가', '문배동', '용산동2가', '원효로4가', '청파동2가', '한강로1가', '삼선동3가',
#          '청파동1가', '보문동3가', '안암동4가', '용산동3가', '궁동', '방이동', '오류동', '행당동',
#          '영등포동', '사근동', '아현동', '망우동', '합정동', '신수동', '마천동', '금호동2가', '성산동',
#          '잠실동', '공덕동', '방학동', '미아동', '번동', '수유동', '우이동', '본동', '상도1동',
#          '동작동', '개봉동', '권농동', '송파동', '가락동', '염리동', '신원동', '고덕동', '염곡동',
#          '망원동', '북아현동', '홍은동', '남가좌동', '홍제동', '연희동', '천연동', '마포동', '중동',
#          '현석동', '대흥동', '도화동', '상수동', '연남동', '신공덕동', '창전동', '서교동', '상암동',
#          '당인동', '하중동', '동교동', '노고산동', '용강동', '구수동', '상봉동', '양평동1가', '양평동2가',
#          '토정동', '북가좌동', '옥천동', '충정로3가', '충정로2가', '영천동', '신촌동', '길동', '명일동',
#          '둔촌동', '강일동', '원효로1가', '산천동', '갈월동', '주성동', '청암동', '청파동3가', '시흥동',
#          '가산동', '신천동', '성내동', '남영동', '남현동', '여의도동', '문래동3가', '당산동2가',
#          '하왕십리동', '마장동', '상왕십리동', '홍익동', '동소문동1가', '동선동4가', '삼선동5가',
#          '삼선동4가', '안암동1가', '동소문동5가', '동소문동2가', '동선동5가', '보문동4가', '성북동1가',
#          '동소문동4가', '보문동2가', '보문동5가', '보문동1가', '동선동3가', '동선동1가', '동소문동6가',
#          '보문동7가', '황학동', '충무로5가', '남창동', '인현동2가', '오장동', '을지로6가', '회현동1가',
#          '입정동', '충무로4가', '을지로5가', '회현동2가', '예장동', '만리동1가', '을지로2가',
#          '남대문로5가', '장지동', '거여동', '삼전동', '석촌동', '장충동2가', '만리동2가', '묵정동',
#          '신길동', '쌍림동', '필동3가', '인현동1가', '남산동2가', '장충동1가', '산림동', '대림동',
#          '구로동', '양평동3가', '영등포동2가', '양평동4가', '당산동5가', '당산동4가', '고척동',
#          '양평동6가', '문래동2가', '당산동', '문래동6가', '양평동5가', '문래동1가', '영등포동8가',
#          '영등포동6가', '당산동3가', '충무로3가', '무학동', '예관동', '필동2가', '충무로1가', '필동1가',
#          '저동2가', '충무로2가', '을지로3가', '광희동2가', '을지로4가', '화동', '저동1가', '문래동5가',
#          '신도림동', '온수동', '도림동', '정동', '천왕동', '가리봉동', '영등포동7가', '영등포동3가',
#          '당산동1가', '영등포동5가', '영등포동1가', '문래동4가', '당산동6가', '영등포동4가', '대현동',
#          '합동', '현저동', '창천동', '냉천동', '봉원동', '대신동', '미근동', '내자동', '봉익동',
#          '와룡동', '궁정동', '다동', '을지로7가', '주교동', '북창동', '동소문동3가', '장사동', '관훈동',
#          '회현동3가', '남산동3가', '남산동1가', '묘동', '방산동', '송월동', '관수동', '오곡동', '공평동',
#          '종로3가', '봉래동1가', '원지동', '수표동'], dtype=object)),
#  ('JOB_GBN_NM', array(['신고', '주택거래신고'], dtype=object)),
#  ('RIGHT_GBN', array(['0', '1', 'A', 'B', '2', nan], dtype=object)),
#  ('BLDG_MUSE_NM', array(['연립주택', '아파트', '단독주택', '오피스텔'], dtype=object)),
#  ('BLDG_NM',
#   array(['(446-11)', '금호타운(380-14)', '신진빌라(141-111)', ..., '경흥빌라',
#          '삼익주택(951-7)', '신월연립'], dtype=object)),
#  ('SGDONG_NM',
#   array(['은평구 갈현동', '금천구 독산동', '은평구 녹번동', '동대문구 장안동', '은평구 불광동', '동작구 흑석동',
#          '은평구 수색동', '동대문구 제기동', '은평구 대조동', '동대문구 휘경동', '동작구 사당동', '은평구 진관동',
#          '동대문구 청량리동', '동작구 상도동', '은평구 응암동', '동대문구 용두동', '강서구 등촌동',
#          '동작구 대방동', '은평구 신사동', '동대문구 답십리동', '은평구 역촌동', '은평구 증산동', '송파구 오금동',
#          '동대문구 이문동', '동대문구 전농동', '강남구 청담동', '광진구 자양동', '강서구 화곡동', '서초구 서초동',
#          '강남구 세곡동', '강서구 방화동', '서초구 방배동', '강남구 역삼동', '광진구 광장동', '강서구 염창동',
#          '서초구 양재동', '은평구 구산동', '광진구 구의동', '강남구 도곡동', '강서구 내발산동', '강남구 삼성동',
#          '강서구 가양동', '서초구 잠원동', '광진구 중곡동', '강남구 수서동', '서초구 반포동', '동대문구 회기동',
#          '강남구 논현동', '중구 의주로1가', '강남구 압구정동', '강남구 개포동', '서초구 우면동', '강남구 대치동',
#          '서초구 내곡동', '중랑구 신내동', '강남구 율현동', '강서구 마곡동', '강남구 자곡동', '광진구 화양동',
#          '종로구 평창동', '종로구 숭인동', '종로구 동숭동', '강남구 신사동', '종로구 창신동', '동작구 신대방동',
#          '종로구 명륜1가', '종로구 익선동', '종로구 구기동', '종로구 내수동', '종로구 무악동', '강서구 공항동',
#          '종로구 혜화동', '종로구 홍지동', '종로구 명륜2가', '광진구 군자동', '종로구 사직동', '종로구 원서동',
#          '종로구 연지동', '종로구 가회동', '광진구 능동', '강남구 일원동', '종로구 신영동', '종로구 부암동',
#          '동작구 노량진동', '종로구 수송동', '종로구 안국동', '종로구 체부동', '동대문구 신설동', '종로구 필운동',
#          '종로구 운니동', '종로구 명륜3가', '종로구 누상동', '종로구 효제동', '종로구 신문로2가',
#          '종로구 청운동', '종로구 경운동', '종로구 홍파동', '종로구 창성동', '종로구 충신동', '종로구 소격동',
#          '종로구 관철동', '종로구 인사동', '종로구 이화동', '종로구 연건동', '종로구 신문로1가', '종로구 신교동',
#          '구로구 항동', '종로구 교북동', '종로구 적선동', '종로구 인의동', '종로구 교남동', '종로구 계동',
#          '종로구 견지동', '종로구 효자동', '종로구 종로1가', '종로구 행촌동', '종로구 종로5가', '종로구 옥인동',
#          '종로구 삼청동', '종로구 사간동', '종로구 평동', '관악구 봉천동', '종로구 명륜4가', '종로구 누하동',
#          '종로구 당주동', '용산구 동자동', '성동구 금호동4가', '성동구 금호동3가', '성동구 옥수동',
#          '중구 신당동', '성동구 도선동', '성동구 용답동', '용산구 보광동', '성동구 송정동', '성동구 성수동1가',
#          '성동구 금호동1가', '중구 중림동', '용산구 서빙고동', '성동구 응봉동', '용산구 신창동', '중구 흥인동',
#          '강서구 개화동', '중구 순화동', '성동구 성수동2가', '중구 광희동1가', '관악구 신림동', '종로구 팔판동',
#          '종로구 종로6가', '종로구 돈의동', '종로구 낙원동', '종로구 재동', '종로구 통인동', '종로구 통의동',
#          '종로구 원남동', '중랑구 면목동', '중랑구 중화동', '강서구 외발산동', '도봉구 창동', '도봉구 도봉동',
#          '도봉구 쌍문동', '노원구 공릉동', '송파구 문정동', '노원구 월계동', '노원구 중계동', '노원구 상계동',
#          '강동구 암사동', '송파구 풍납동', '중랑구 묵동', '성북구 장위동', '성북구 종암동', '성북구 정릉동',
#          '성북구 삼선동2가', '노원구 하계동', '성북구 동선동2가', '성북구 돈암동', '성북구 동소문동7가',
#          '성북구 석관동', '성북구 하월곡동', '양천구 신월동', '강동구 상일동', '성북구 성북동',
#          '용산구 용산동5가', '강동구 천호동', '성북구 길음동', '성북구 안암동2가', '성북구 상월곡동',
#          '양천구 신정동', '용산구 한남동', '성북구 안암동5가', '용산구 이촌동', '용산구 효창동',
#          '성북구 보문동6가', '용산구 한강로2가', '성북구 안암동3가', '성북구 삼선동1가', '용산구 이태원동',
#          '용산구 후암동', '양천구 목동', '용산구 동빙고동', '용산구 한강로3가', '용산구 원효로3가',
#          '용산구 용문동', '용산구 신계동', '용산구 서계동', '용산구 도원동', '용산구 원효로2가', '용산구 문배동',
#          '용산구 용산동2가', '용산구 원효로4가', '용산구 청파동2가', '용산구 한강로1가', '성북구 삼선동3가',
#          '용산구 청파동1가', '성북구 보문동3가', '성북구 안암동4가', '용산구 용산동3가', '구로구 궁동',
#          '송파구 방이동', '구로구 오류동', '성동구 행당동', '영등포구 영등포동', '성동구 사근동', '마포구 아현동',
#          '중랑구 망우동', '마포구 합정동', '마포구 신수동', '송파구 마천동', '성동구 금호동2가', '마포구 성산동',
#          '송파구 잠실동', '마포구 공덕동', '도봉구 방학동', '강북구 미아동', '강북구 번동', '강북구 수유동',
#          '강북구 우이동', '동작구 본동', '동작구 상도1동', '동작구 동작동', '구로구 개봉동', '종로구 권농동',
#          '송파구 송파동', '송파구 가락동', '마포구 염리동', '서초구 신원동', '강동구 고덕동', '서초구 염곡동',
#          '마포구 망원동', '서대문구 북아현동', '서대문구 홍은동', '서대문구 남가좌동', '서대문구 홍제동',
#          '서대문구 연희동', '서대문구 천연동', '마포구 마포동', '마포구 중동', '마포구 현석동', '마포구 대흥동',
#          '마포구 도화동', '마포구 상수동', '마포구 연남동', '마포구 신공덕동', '마포구 창전동', '마포구 서교동',
#          '마포구 상암동', '마포구 당인동', '마포구 하중동', '마포구 동교동', '마포구 노고산동', '마포구 용강동',
#          '마포구 구수동', '마포구 신정동', '중랑구 상봉동', '영등포구 양평동1가', '영등포구 양평동2가',
#          '마포구 토정동', '서대문구 북가좌동', '서대문구 옥천동', '서대문구 충정로3가', '서대문구 충정로2가',
#          '서대문구 영천동', '서대문구 신촌동', '강동구 길동', '강동구 명일동', '강동구 둔촌동', '강동구 강일동',
#          '용산구 원효로1가', '용산구 산천동', '용산구 갈월동', '용산구 주성동', '용산구 청암동',
#          '용산구 청파동3가', '금천구 시흥동', '금천구 가산동', '송파구 신천동', '강동구 성내동', '용산구 남영동',
#          '관악구 남현동', '영등포구 여의도동', '영등포구 문래동3가', '영등포구 당산동2가', '성동구 하왕십리동',
#          '성동구 마장동', '성동구 상왕십리동', '성동구 홍익동', '성북구 동소문동1가', '성북구 동선동4가',
#          '성북구 삼선동5가', '성북구 삼선동4가', '성북구 안암동1가', '성북구 동소문동5가', '성북구 동소문동2가',
#          '성북구 동선동5가', '성북구 보문동4가', '성북구 성북동1가', '성북구 동소문동4가', '성북구 보문동2가',
#          '성북구 보문동5가', '성북구 보문동1가', '성북구 동선동3가', '성북구 동선동1가', '성북구 동소문동6가',
#          '성북구 보문동7가', '중구 황학동', '중구 충무로5가', '중구 남창동', '중구 인현동2가', '중구 오장동',
#          '중구 을지로6가', '중구 회현동1가', '중구 입정동', '중구 충무로4가', '중구 을지로5가',
#          '중구 회현동2가', '중구 예장동', '중구 만리동1가', '중구 을지로2가', '중구 남대문로5가',
#          '송파구 장지동', '송파구 거여동', '송파구 삼전동', '송파구 석촌동', '중구 장충동2가', '중구 만리동2가',
#          '중구 묵정동', '영등포구 신길동', '중구 쌍림동', '중구 필동3가', '중구 인현동1가', '중구 남산동2가',
#          '중구 장충동1가', '중구 산림동', '영등포구 대림동', '구로구 구로동', '영등포구 양평동3가',
#          '영등포구 영등포동2가', '영등포구 양평동4가', '영등포구 당산동5가', '영등포구 당산동4가', '구로구 고척동',
#          '영등포구 양평동6가', '영등포구 문래동2가', '영등포구 당산동', '영등포구 문래동6가', '영등포구 양평동5가',
#          '영등포구 문래동1가', '영등포구 영등포동8가', '영등포구 영등포동6가', '영등포구 당산동3가',
#          '중구 충무로3가', '중구 무학동', '중구 예관동', '중구 필동2가', '중구 충무로1가', '중구 필동1가',
#          '중구 저동2가', '중구 충무로2가', '중구 을지로3가', '중구 광희동2가', '중구 을지로4가',
#          '종로구 화동', '중구 저동1가', '영등포구 문래동5가', '구로구 신도림동', '구로구 온수동',
#          '영등포구 도림동', '중구 정동', '구로구 천왕동', '구로구 가리봉동', '영등포구 영등포동7가',
#          '영등포구 영등포동3가', '영등포구 당산동1가', '영등포구 영등포동5가', '영등포구 영등포동1가',
#          '영등포구 문래동4가', '영등포구 당산동6가', '영등포구 영등포동4가', '서대문구 대현동', '서대문구 합동',
#          '서대문구 현저동', '서대문구 창천동', '서대문구 냉천동', '서대문구 봉원동', '서대문구 대신동',
#          '서대문구 미근동', '종로구 내자동', '종로구 봉익동', '종로구 와룡동', '종로구 궁정동', '중구 다동',
#          '중구 을지로7가', '중구 주교동', '중구 북창동', '성북구 동소문동3가', '종로구 장사동', '종로구 관훈동',
#          '중구 회현동3가', '중구 남산동3가', '중구 남산동1가', '종로구 묘동', '중구 방산동', '종로구 송월동',
#          '종로구 관수동', '강서구 오곡동', '종로구 공평동', '종로구 종로3가', '중구 봉래동1가', '서초구 원지동',
#          '중구 수표동'], dtype=object))]

# %% [markdown]
# * 높은 카디널리티 는 값이 매우 드물거나 고유 한 열을 나타냅니다. 대부분의 시계열 데이터 세트에 높은 카디널리티 데이터가 얼마나 많이 포함되어 있는지를 감안할 때 향후 모델을 혼동하지 않도록 데이터 세트에서 이러한 높은 카디널리티 열을 완전히 제거하여이 문제를 직접 해결할 것입니다.

# %%
from scipy import stats
#histogram and normal probability plot
sns.distplot(train['OBJ_AMT'], hist=True);
fig = plt.figure()
res = stats.probplot(train['OBJ_AMT'], plot=plt)

# %% [markdown]
# 타겟인 집값의 분포도 이상치도 존재하고 왼쪽으로 치우쳐져 있다.

# %%
train[train['BLDG_MUSE_NM']== '아파트'].head()
# Out:
#                        RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326970  11230-2018-4-0009724-1  1123010600103360000   11230   동대문구
# 326971  11380-2018-4-0010779-1  1138010300102300003   11380    은평구
# 326978  11230-2018-4-0009727-1  1123010900101280012   11230   동대문구
# 326980  11590-2018-4-0011173-1  1159010700111340000   11590    동작구
# 326981  11380-2018-4-0010770-1  1138011400100270000   11380    은평구
#
#         BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326970   1123010600       장안동      2018        4         신고          1
# 326971   1138010300       불광동      2018        4         신고          1
# 326978   1123010900       휘경동      2018        4         신고          1
# 326980   1159010700       사당동      2018        4         신고          1
# 326981   1138011400       진관동      2018        4         신고          1
#
#         TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326970       NaN      84.87         0      11.0          2001          아파트
# 326971       NaN      56.40         0       8.0          2001          아파트
# 326978       0.0      84.31         1       5.0          2001          아파트
# 326980       NaN      84.98         0      14.0          2001          아파트
# 326981       0.0     166.19         A       4.0          2001          아파트
#
#           OBJ_AMT               BLDG_NM  BUILD_YEAR SGDONG_NM
# 326970  600000000          장안현대홈타운(336)      2003.0  동대문구 장안동
# 326971  285900000                 대암아파트      1997.0   은평구 불광동
# 326978  709700000           휘경 SK VIEW          0.0  동대문구 휘경동
# 326980  589000000              경남아너스빌1차      1997.0   동작구 사당동
# 326981  681740000  은평뉴타운 구파발(금호어울림10단지)         0.0   은평구 진관동

# %%
train['JOB_GBN_NM'].value_counts()
# Out:
# 신고        1288876
# 주택거래신고      22564
# Name: JOB_GBN_NM, dtype: int64

# %%
train['JOB_GBN'].value_counts()
# Out:
# 4    1288876
# 9      22564
# Name: JOB_GBN, dtype: int64

# %%
train['RIGHT_GBN'].value_counts()
# Out:
# 0    1268336
# 1      25205
# 2      16434
# A        843
# B        621
# Name: RIGHT_GBN, dtype: int64

# %% [markdown]
# 층정보와 대지권 면적(TOT_AREA)을 같이 기입을 안한 자료도 있는 것이 보입니다. 0.0이란값은 null이라고 생각하고 데이터 분석을 진행하겠습니다.

# %%
train[(train['FLR_INFO']== 0) & (train['TOT_AREA']== 0)].head()
# Out:
#                        RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 369679  11230-2018-4-0006998-1  1153010700102080003   11230    구로구
# 492974  11380-2017-4-0000008-1  1138010700106260108   11380    은평구
# 509454  11380-2017-4-0008162-1  1138011400100880013   11380    은평구
# 644820  11170-2017-4-0001311-1  1117012500103420000   11170    용산구
# 683801  11230-2016-4-0000716-1  1123010600103730003   11230   동대문구
#
#         BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 369679   1153010700       개봉동      2018        4         신고          1
# 492974   1138010700       응암동      2017        4         신고          1
# 509454   1138011400       진관동      2017        4         신고          1
# 644820   1117012500     한강로2가      2017        4         신고          1
# 683801   1123010600       장안동      2016        4         신고          1
#
#         TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 369679       0.0      14.22         1       0.0          2001          아파트
# 492974       0.0      59.79         2       0.0          2001          아파트
# 509454       0.0      41.88         1       0.0          2001          아파트
# 644820       0.0      34.02         1       0.0          2001          아파트
# 683801       0.0      18.35         1       0.0          2001          아파트
#
#           OBJ_AMT       BLDG_NM  BUILD_YEAR  SGDONG_NM
# 369679  184100000  한양아이클래스(도시형)         0.0    구로구 개봉동
# 492974  371100000       백련산파크자이         0.0    은평구 응암동
# 509454  395600000      은평스카이뷰자이         0.0    은평구 진관동
# 644820  511000000        래미안 용산         0.0  용산구 한강로2가
# 683801  119400000    현대 썬앤빌 601         0.0   동대문구 장안동

# %%
train[train['TOT_AREA']== 0].head()
# Out:
#                        RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326978  11230-2018-4-0009727-1  1123010900101280012   11230   동대문구
# 326981  11380-2018-4-0010770-1  1138011400100270000   11380    은평구
# 326987  11380-2018-4-0010754-1  1138011400100840000   11380    은평구
# 327008  11710-2018-4-0008361-1  1171011200106190000   11710    송파구
# 327019  11380-2018-4-0010738-1  1138010300106450000   11380    은평구
#
#         BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326978   1123010900       휘경동      2018        4         신고          1
# 326981   1138011400       진관동      2018        4         신고          1
# 326987   1138011400       진관동      2018        4         신고          1
# 327008   1171011200       오금동      2018        4         신고          1
# 327019   1138010300       불광동      2018        4         신고          1
#
#         TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326978       0.0      84.31         1       5.0          2001          아파트
# 326981       0.0     166.19         A       4.0          2001          아파트
# 326987       0.0     167.71         A       2.0          2001          아파트
# 327008       0.0     101.46         A      17.0          2001          아파트
# 327019       0.0      59.99         B      12.0          2001          아파트
#
#           OBJ_AMT               BLDG_NM  BUILD_YEAR SGDONG_NM
# 326978  709700000           휘경 SK VIEW          0.0  동대문구 휘경동
# 326981  681740000  은평뉴타운 구파발(금호어울림10단지)         0.0   은평구 진관동
# 326987  698550000    은평뉴타운 우물골(두산위브7단지)         0.0   은평구 진관동
# 327008  853050000          송파호반베르디움더퍼스트         0.0   송파구 오금동
# 327019  570000000                불광롯데캐슬         0.0   은평구 불광동

# %% [markdown]
# ## 데이터 전처리
# - 결측치 제거 혹은 대체
#
# - Feature Engineering
#
# - 데이터의 정규화
#
# - 노이즈 제거
#
# - 데이터 밸런스

# %% [markdown]
# ### 결측치 처리

# %%
train.isnull().sum().sort_values()
# Out:
# RTMS_ID              0
# OBJ_AMT              0
# BLDG_MUSE_NM         0
# BLDG_MUSE_CD         0
# BLDG_AREA            0
# JOB_GBN_NM           0
# JOB_GBN              0
# OBJ_SEQNO            0
# BJDONG_NM            0
# BJDONG10_CD          0
# SGG_NM               0
# SGG_CD               0
# LAND_CD              0
# ACC_YEAR             0
# SGDONG_NM            0
# RIGHT_GBN            1
# BUILD_YEAR        3867
# FLR_INFO        105763
# BLDG_NM         105763
# TOT_AREA        711918
# dtype: int64

# %%
# BUILD_YEAR 건축년도가 0.0 인 부분도 결측치로 생각
train[(train['BUILD_YEAR'].isnull()) | (train['BUILD_YEAR']== 0)]
# Out:
#                         RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326978   11230-2018-4-0009727-1  1123010900101280012   11230   동대문구
# 326981   11380-2018-4-0010770-1  1138011400100270000   11380    은평구
# 326987   11380-2018-4-0010754-1  1138011400100840000   11380    은평구
# 327008   11710-2018-4-0008361-1  1171011200106190000   11710    송파구
# 327019   11380-2018-4-0010738-1  1138010300106450000   11380    은평구
# ...                         ...                  ...     ...    ...
# 1638335  11470-2010-4-0002493-1           1147010100   11470    양천구
# 1638358  11470-2010-4-0002631-1           1147010300   11470    양천구
# 1638384  11470-2010-4-0002622-1           1147010300   11470    양천구
# 1638385  11470-2010-4-0002596-1           1147010200   11470    양천구
# 1638390  11470-2010-4-0002572-1           1147010100   11470    양천구
#
#          BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326978    1123010900       휘경동      2018        4         신고          1
# 326981    1138011400       진관동      2018        4         신고          1
# 326987    1138011400       진관동      2018        4         신고          1
# 327008    1171011200       오금동      2018        4         신고          1
# 327019    1138010300       불광동      2018        4         신고          1
# ...              ...       ...       ...      ...        ...        ...
# 1638335   1147010100       신정동      2010        4         신고          1
# 1638358   1147010300       신월동      2010        4         신고          1
# 1638384   1147010300       신월동      2010        4         신고          1
# 1638385   1147010200        목동      2010        4         신고          1
# 1638390   1147010100       신정동      2010        4         신고          1
#
#          TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326978        0.0      84.31         1       5.0          2001          아파트
# 326981        0.0     166.19         A       4.0          2001          아파트
# 326987        0.0     167.71         A       2.0          2001          아파트
# 327008        0.0     101.46         A      17.0          2001          아파트
# 327019        0.0      59.99         B      12.0          2001          아파트
# ...           ...        ...       ...       ...           ...          ...
# 1638335      90.3     149.70         0       NaN          1001         단독주택
# 1638358     130.0     301.28         0       NaN          1001         단독주택
# 1638384     121.0     191.04         0       NaN          1001         단독주택
# 1638385     200.0     465.12         0       NaN          1001         단독주택
# 1638390      88.1     146.68         0       NaN          1001         단독주택
#
#            OBJ_AMT               BLDG_NM  BUILD_YEAR SGDONG_NM
# 326978   709700000           휘경 SK VIEW          0.0  동대문구 휘경동
# 326981   681740000  은평뉴타운 구파발(금호어울림10단지)         0.0   은평구 진관동
# 326987   698550000    은평뉴타운 우물골(두산위브7단지)         0.0   은평구 진관동
# 327008   853050000          송파호반베르디움더퍼스트         0.0   송파구 오금동
# 327019   570000000                불광롯데캐슬         0.0   은평구 불광동
# ...            ...                   ...         ...       ...
# 1638335  514000000                   NaN         NaN   양천구 신정동
# 1638358  550000000                   NaN         NaN   양천구 신월동
# 1638384  370000000                   NaN         NaN   양천구 신월동
# 1638385  945000000                   NaN         NaN    양천구 목동
# 1638390  500000000                   NaN         NaN   양천구 신정동
#
# [46973 rows x 20 columns]

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# 결측치의 경우 SimpleImputer의 가장 빈번한 값으로 결측치 처리

# %% [markdown]
# - 대지면적 : 대지의 수평투영면적. 건축선(도로에 인접한 건축물의 경우 도로로 부터 공간확보를 위해 건축을 제한해놓은 건축가능 경계선)과 도로사이의 면적 및 도시계획시설 면적은 제외함.
#
# -  건축면적 : 건축물 외벽의 중심선으로 둘러싸인 부분의 수평투영면적. (지표면으로부터 1m 이하에 있는 부분은 제외)
# 대지지분은 집 값에 중요한 요소
#
# 대지지분 = 대지면적/세대수
#
# 대지권 면적(TOT_AREA)
#
# 대지지분이란 아파트(공동주택) 전체 대지면적을 세대수로 나눈 면적을 말합니다. 즉 내가 소유한 주택이 아파트 전체 면적에서 차지하는 면적을 말하는데요. 이 대지지분을 전용면적으로 나눈 비율을 대지지분 율이라고 합니다. 대지지분당 가격을 확인해보는 것이 객관적인 아파트의 가치를 평가할 수 있는 기준입니다.
#
# 주어진 데이터에서 세대수를 구하거나 예측하는 것은 어렵습니다. 하지만 대지지분을 봤을때 대지면적이 클 수록 대지지분은 높아진다고 볼 수있습니다.
#
# https://1boon.kakao.com/ktestate/1025

# %% [markdown]
# 아파트데이터들은 대지권면적이 모두 등기가 되어 있지 않습니다.
#
# 연면적 : 건축면적 * 층 수 (건축물의 바닥면적을 모두 합한 것을 말한다. 총면적)

# %%
raw_df_2019[raw_df_2019['건물주용도'] == '아파트']['대지권면적'].value_counts()
# Out:
# 0.0    61149
# Name: 대지권면적, dtype: int64

# %%
# 이상치 확인
plt.figure(figsize=(18,6))
sns.scatterplot(x=train.index, y= train['OBJ_AMT']);

# %%
# low_sales = train.OBJ_AMT.quantile(0.01)
# high_sales = train.OBJ_AMT.quantile(0.98)

# train = train[(train.OBJ_AMT >= low_sales) & (train.OBJ_AMT <= high_sales)]
# plt.figure(figsize=(18,6))

# sns.scatterplot(x=train.index, y=train['OBJ_AMT'])
# plt.xticks(rotation=90)

# %%
train
# Out:
#                         RTMS_ID              LAND_CD  SGG_CD SGG_NM  \
# 326967   11380-2018-4-0010781-1  1138010400104460011   11380    은평구
# 326968   11545-2018-4-0005964-1  1154510200103800014   11545    금천구
# 326969   11380-2018-4-0010780-1  1138010200101410111   11380    은평구
# 326970   11230-2018-4-0009724-1  1123010600103360000   11230   동대문구
# 326971   11380-2018-4-0010779-1  1138010300102300003   11380    은평구
# ...                         ...                  ...     ...    ...
# 1638402  11470-2010-4-0002601-1  1147010300101230031   11470    양천구
# 1638403  11470-2010-4-0002612-1  1147010300110250000   11470    양천구
# 1638404  11470-2010-4-0002609-1  1147010200109010000   11470    양천구
# 1638405  11470-2010-4-0002607-1  1147010100113140000   11470    양천구
# 1638406  11470-2010-4-0002610-1  1147010200107090002   11470    양천구
#
#          BJDONG10_CD BJDONG_NM  ACC_YEAR  JOB_GBN JOB_GBN_NM  OBJ_SEQNO  \
# 326967    1138010400       갈현동      2018        4         신고          1
# 326968    1154510200       독산동      2018        4         신고          1
# 326969    1138010200       녹번동      2018        4         신고          1
# 326970    1123010600       장안동      2018        4         신고          1
# 326971    1138010300       불광동      2018        4         신고          1
# ...              ...       ...       ...      ...        ...        ...
# 1638402   1147010300       신월동      2010        4         신고          1
# 1638403   1147010300       신월동      2010        4         신고          1
# 1638404   1147010200        목동      2010        4         신고          1
# 1638405   1147010100       신정동      2010        4         신고          1
# 1638406   1147010200        목동      2010        4         신고          1
#
#          TOT_AREA  BLDG_AREA RIGHT_GBN  FLR_INFO  BLDG_MUSE_CD BLDG_MUSE_NM  \
# 326967      23.61      31.06         0       1.0          2002         연립주택
# 326968      28.67      48.54         0       3.0          2002         연립주택
# 326969      21.22      31.56         0      -1.0          2002         연립주택
# 326970        NaN      84.87         0      11.0          2001          아파트
# 326971        NaN      56.40         0       8.0          2001          아파트
# ...           ...        ...       ...       ...           ...          ...
# 1638402     22.04      38.02         0       3.0          2002         연립주택
# 1638403       NaN      81.75         0       2.0          2001          아파트
# 1638404       NaN      47.52         0       5.0          2001          아파트
# 1638405       NaN     144.38         0       3.0          2001          아파트
# 1638406       NaN      59.90         0       9.0          2001          아파트
#
#            OBJ_AMT        BLDG_NM  BUILD_YEAR SGDONG_NM
# 326967    80000000       (446-11)      1987.0   은평구 갈현동
# 326968   180000000   금호타운(380-14)      2001.0   금천구 독산동
# 326969    67000000  신진빌라(141-111)      1991.0   은평구 녹번동
# 326970   600000000   장안현대홈타운(336)      2003.0  동대문구 장안동
# 326971   285900000          대암아파트      1997.0   은평구 불광동
# ...            ...            ...         ...       ...
# 1638402  149000000        SK그랑빌5차      2009.0   양천구 신월동
# 1638403  299500000          탑건진선미      2004.0   양천구 신월동
# 1638404  515000000        목동신시가지1      1985.0    양천구 목동
# 1638405  952400000          중앙하이츠      2010.0   양천구 신정동
# 1638406  289000000            성원2      2000.0    양천구 목동
#
# [1311440 rows x 20 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1311440 entries, 326967 to 1638406
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   RTMS_ID       1311440 non-null  object
#  1   LAND_CD       1311440 non-null  object
#  2   SGG_CD        1311440 non-null  int64
#  3   SGG_NM        1311440 non-null  object
#  4   BJDONG10_CD   1311440 non-null  int64
#  5   BJDONG_NM     1311440 non-null  object
#  6   ACC_YEAR      1311440 non-null  int64
#  7   JOB_GBN       1311440 non-null  int64
#  8   JOB_GBN_NM    1311440 non-null  object
#  9   OBJ_SEQNO     1311440 non-null  int64
#  10  TOT_AREA      599522 non-null   float64
#  11  BLDG_AREA     1311440 non-null  float64
#  12  RIGHT_GBN     1311439 non-null  object
#  13  FLR_INFO      1205677 non-null  float64
#  14  BLDG_MUSE_CD  1311440 non-null  int64
#  15  BLDG_MUSE_NM  1311440 non-null  object
#  16  OBJ_AMT       1311440 non-null  int64
#  17  BLDG_NM       1205677 non-null  object
#  18  BUILD_YEAR    1307573 non-null  float64
#  19  SGDONG_NM     1311440 non-null  object
# dtypes: float64(4), int64(7), object(9)
# memory usage: 210.1+ MB

# %%
def wrangle(df):
    df = df.copy()
    
    # 서울시 아파트에 대해서만 
    df = df[df['BLDG_MUSE_NM'] == '아파트']
    
    df['FLR_INFO'] = df['FLR_INFO'].apply(pd.to_numeric)
    df['TOT_AREA'] = df['TOT_AREA'].apply(pd.to_numeric)
    
    df['ACC_YEAR'] = df['ACC_YEAR'].astype('int64')
    df['SGG_NM'] = df['SGG_NM'].astype('category')
    
    # 연면적 추가
    df['YEON_AREA'] = df['FLR_INFO'] * df['BLDG_AREA']  
    # 이상치 제거
    low_sales = df.OBJ_AMT.quantile(0.01)
    high_sales = df.OBJ_AMT.quantile(0.98)
    df = df[(df.OBJ_AMT >= low_sales) & (df.OBJ_AMT <= high_sales)]

    # 높은 카디널리티는 삭제
    df = df.drop(columns=['RTMS_ID', 'LAND_CD', 'BJDONG_NM', 'BLDG_NM', 'SGDONG_NM'], axis=1)
    
    # 가격과 관련이 없는 컬럼 삭제
    df = df.drop(columns=['TOT_AREA', 'SGG_CD', 'RIGHT_GBN', 'BLDG_MUSE_NM', 'BLDG_MUSE_CD', 'JOB_GBN', 'JOB_GBN_NM'], axis=1)
    
    df = df.reset_index(drop=True)
    
    return df

train = wrangle(train)
val = wrangle(test)
test = wrangle(test)

# %%
train.shape, val.shape, test.shape
# Out:
# ((732440, 9), (94482, 9), (94482, 9))

# %%
corrMatrix = train.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show();

# %% [markdown]
# # 모델 설계
#
# 1) 모델을 학습한 후에 베이스라인보다 잘 나왔나요? 그렇지 않다면 그 이유는 무엇일까요?
#
# 2) 모델 성능 개선을 위해 어떤 방법을 적용했나요? 그 방법을 선택한 이유는 무엇인가요?
#
# 3) 최종 모델에 관해 설명하세요.

# %% [markdown]
# **기준모델**
#
# 예측을 수행하고 평가하기 전에 합리적인 측정 기준을 설정해야 합니다. 서울시 아파트 사례의 기본 예측은 연간 서울시 집값이 될 것입니다. 즉, 기준선은 대상 데이터 세트(y_train)의 평균 집값을 단순히 예측한 경우 발생할 수 있는 오류입니다.

# %%
predict = train['OBJ_AMT'].mean()
errors = predict - train['OBJ_AMT']

# %%
errors
# Out:
# 0        -1.023939e+08
# 1         2.117061e+08
# 2        -2.120939e+08
# 3        -9.139386e+07
# 4        -1.841339e+08
#               ...
# 732435    2.876061e+08
# 732436    1.981061e+08
# 732437   -1.739386e+07
# 732438   -4.547939e+08
# 732439    2.086061e+08
# Name: OBJ_AMT, Length: 732440, dtype: float64

# %%
base_mae = errors.abs().mean()
base_mae
# Out:
# 202072233.99531874

# %%
print(f'예측한 주택 가격이 ${predict:,.0f}이며 절대평균에러가 ${base_mae:,.0f}임을 확인할 수 있습니다.')
# Out:
# 예측한 주택 가격이 $497,606,136이며 절대평균에러가 $202,072,234임을 확인할 수 있습니다.

# %% [markdown]
# **target값 분류**

# %%
target = 'OBJ_AMT'
features = train.columns.drop('OBJ_AMT')

X_train = train[features]
y_train = np.log1p(train[target])
X_val = val[features]
y_val = np.log1p(val[target])
X_test = test[features]
y_test = np.log1p(test[target])

# %%
# right skward 분포를 띄고 있어 log를 취해줬다.

import seaborn as sns

sns.displot(y_train, kde=True)

# %% [markdown]
# # 3가지 모델 비교

# %% [markdown]
# ## Linear

# %%
from category_encoders import OrdinalEncoder, TargetEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import f_regression, SelectKBest

lm = make_pipeline(
    TargetEncoder(),
    SimpleImputer(strategy='most_frequent'),
    StandardScaler(),
    LinearRegression()
)

lm.fit(X_train, y_train)
print('R^2', lm.score(X_val, y_val))
# Out:
# R^2 0.27068605286040803

# %% [markdown]
# ## Ensemble
#
# - Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rm= make_pipeline(
    TargetEncoder(),
    SimpleImputer(strategy='most_frequent'),
    StandardScaler(),
    RandomForestRegressor(n_estimators=100, max_depth=50, random_state=42, n_jobs=-1)
)

# %%
rm.fit(X_train, y_train)
rm.score(X_val, y_val)
# Out:
# 0.5990404656036722

# %% [markdown]
# ## XGBoost 모델

# %%
from category_encoders import OrdinalEncoder
from sklearn.metrics import r2_score
from xgboost import XGBRegressor

encoder = OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train) # 학습데이터
X_val_encoded = encoder.transform(X_val) # 검증데이터

boosting = XGBRegressor(
    n_estimators=200,
    objective='reg:squarederror', # default
    learning_rate=0.2,
    n_jobs=-1
)

eval_set = [(X_train_encoded, y_train), 
            (X_val_encoded, y_val)]

boosting.fit(X_train_encoded, y_train, 
          eval_set=eval_set,
          early_stopping_rounds=50
         )
# Out:
# [0]	validation_0-rmse:15.52370	validation_1-rmse:15.98902
# [1]	validation_0-rmse:12.42006	validation_1-rmse:12.87053
# [2]	validation_0-rmse:9.93728	validation_1-rmse:10.37956
# [3]	validation_0-rmse:7.95131	validation_1-rmse:8.38627
# [4]	validation_0-rmse:6.36271	validation_1-rmse:6.79276
# [5]	validation_0-rmse:5.09199	validation_1-rmse:5.51505
# [6]	validation_0-rmse:4.07574	validation_1-rmse:4.49233
# [7]	validation_0-rmse:3.26296	validation_1-rmse:3.67263
# [8]	validation_0-rmse:2.61329	validation_1-rmse:3.00680
# [9]	validation_0-rmse:2.09408	validation_1-rmse:2.48368
# [10]	validation_0-rmse:1.67939	validation_1-rmse:2.06171
# [11]	validation_0-rmse:1.34846	validation_1-rmse:1.72348
# [12]	validation_0-rmse:1.08469	validation_1-rmse:1.45527
# [13]	validation_0-rmse:0.87488	validation_1-rmse:1.23921
# [14]	validation_0-rmse:0.70857	validation_1-rmse:1.06899
# [15]	validation_0-rmse:0.57698	validation_1-rmse:0.92766
# [16]	validation_0-rmse:0.47386	validation_1-rmse:0.82140
# [17]	validation_0-rmse:0.39348	validation_1-rmse:0.73322
# [18]	validation_0-rmse:0.33165	validation_1-rmse:0.66589
# [19]	validation_0-rmse:0.28527	validation_1-rmse:0.60908
# [20]	validation_0-rmse:0.25042	validation_1-rmse:0.56716
# [21]	validation_0-rmse:0.22529	validation_1-rmse:0.53359
# [22]	validation_0-rmse:0.20592	validation_1-rmse:0.50818
# [23]	validation_0-rmse:0.19330	validation_1-rmse:0.48434
# [24]	validation_0-rmse:0.18363	validation_1-rmse:0.46761
# [25]	validation_0-rmse:0.17663	validation_1-rmse:0.45382
# [26]	validation_0-rmse:0.17248	validation_1-rmse:0.44101
# [27]	validation_0-rmse:0.16825	validation_1-rmse:0.43281
# [28]	validation_0-rmse:0.16598	validation_1-rmse:0.42669
# [29]	validation_0-rmse:0.16466	validation_1-rmse:0.41916
# [30]	validation_0-rmse:0.16226	validation_1-rmse:0.41450
# [31]	validation_0-rmse:0.16000	validation_1-rmse:0.41080
# [32]	validation_0-rmse:0.15917	validation_1-rmse:0.40515
# [33]	validation_0-rmse:0.15858	validation_1-rmse:0.40313
# [34]	validation_0-rmse:0.15785	validation_1-rmse:0.39992
# [35]	validation_0-rmse:0.15753	validation_1-rmse:0.39839
# [36]	validation_0-rmse:0.15693	validation_1-rmse:0.39675
# [37]	validation_0-rmse:0.15663	validation_1-rmse:0.39580
# [38]	validation_0-rmse:0.15619	validation_1-rmse:0.39520
# [39]	validation_0-rmse:0.15540	validation_1-rmse:0.39387
# [40]	validation_0-rmse:0.15478	validation_1-rmse:0.39179
# [41]	validation_0-rmse:0.15461	validation_1-rmse:0.39143
# [42]	validation_0-rmse:0.15390	validation_1-rmse:0.39090
# [43]	validation_0-rmse:0.15357	validation_1-rmse:0.39056
# [44]	validation_0-rmse:0.15340	validation_1-rmse:0.39015
# [45]	validation_0-rmse:0.15325	validation_1-rmse:0.38991
# [46]	validation_0-rmse:0.15287	validation_1-rmse:0.38883
# [47]	validation_0-rmse:0.15174	validation_1-rmse:0.38822
# [48]	validation_0-rmse:0.15117	validation_1-rmse:0.38780
# [49]	validation_0-rmse:0.15083	validation_1-rmse:0.38765
# [50]	validation_0-rmse:0.15070	validation_1-rmse:0.38751
# [51]	validation_0-rmse:0.15018	validation_1-rmse:0.38697
# [52]	validation_0-rmse:0.14969	validation_1-rmse:0.38675
# [53]	validation_0-rmse:0.14961	validation_1-rmse:0.38583
# [54]	validation_0-rmse:0.14882	validation_1-rmse:0.38551
# [55]	validation_0-rmse:0.14742	validation_1-rmse:0.38499
# [56]	validation_0-rmse:0.14660	validation_1-rmse:0.38453
# [57]	validation_0-rmse:0.14628	validation_1-rmse:0.38433
# [58]	validation_0-rmse:0.14557	validation_1-rmse:0.38405
# [59]	validation_0-rmse:0.14528	validation_1-rmse:0.38360
# [60]	validation_0-rmse:0.14497	validation_1-rmse:0.38326
# [61]	validation_0-rmse:0.14479	validation_1-rmse:0.38320
# [62]	validation_0-rmse:0.14385	validation_1-rmse:0.38267
# [63]	validation_0-rmse:0.14333	validation_1-rmse:0.38240
# [64]	validation_0-rmse:0.14291	validation_1-rmse:0.38211
# [65]	validation_0-rmse:0.14239	validation_1-rmse:0.38205
# [66]	validation_0-rmse:0.14188	validation_1-rmse:0.38189
# [67]	validation_0-rmse:0.14158	validation_1-rmse:0.38188
# [68]	validation_0-rmse:0.14113	validation_1-rmse:0.38169
# [69]	validation_0-rmse:0.14089	validation_1-rmse:0.38156
# [70]	validation_0-rmse:0.14070	validation_1-rmse:0.38049
# [71]	validation_0-rmse:0.14057	validation_1-rmse:0.38033
# [72]	validation_0-rmse:0.13986	validation_1-rmse:0.38011
# [73]	validation_0-rmse:0.13970	validation_1-rmse:0.37992
# [74]	validation_0-rmse:0.13941	validation_1-rmse:0.37996
# [75]	validation_0-rmse:0.13914	validation_1-rmse:0.37978
# [76]	validation_0-rmse:0.13881	validation_1-rmse:0.37949
# [77]	validation_0-rmse:0.13854	validation_1-rmse:0.37928
# [78]	validation_0-rmse:0.13813	validation_1-rmse:0.37894
# [79]	validation_0-rmse:0.13770	validation_1-rmse:0.37879
# [80]	validation_0-rmse:0.13744	validation_1-rmse:0.37879
# [81]	validation_0-rmse:0.13715	validation_1-rmse:0.37859
# [82]	validation_0-rmse:0.13700	validation_1-rmse:0.37748
# [83]	validation_0-rmse:0.13690	validation_1-rmse:0.37753
# [84]	validation_0-rmse:0.13656	validation_1-rmse:0.37746
# [85]	validation_0-rmse:0.13645	validation_1-rmse:0.37744
# [86]	validation_0-rmse:0.13630	validation_1-rmse:0.37736
# [87]	validation_0-rmse:0.13612	validation_1-rmse:0.37645
# [88]	validation_0-rmse:0.13571	validation_1-rmse:0.37624
# [89]	validation_0-rmse:0.13565	validation_1-rmse:0.37615
# [90]	validation_0-rmse:0.13531	validation_1-rmse:0.37590
# [91]	validation_0-rmse:0.13509	validation_1-rmse:0.37607
# [92]	validation_0-rmse:0.13470	validation_1-rmse:0.37562
# [93]	validation_0-rmse:0.13443	validation_1-rmse:0.37534
# [94]	validation_0-rmse:0.13418	validation_1-rmse:0.37526
# [95]	validation_0-rmse:0.13414	validation_1-rmse:0.37522
# [96]	validation_0-rmse:0.13396	validation_1-rmse:0.37519
# [97]	validation_0-rmse:0.13347	validation_1-rmse:0.37499
# [98]	validation_0-rmse:0.13339	validation_1-rmse:0.37501
# [99]	validation_0-rmse:0.13312	validation_1-rmse:0.37494
# [100]	validation_0-rmse:0.13274	validation_1-rmse:0.37485
# [101]	validation_0-rmse:0.13252	validation_1-rmse:0.37423
# [102]	validation_0-rmse:0.13232	validation_1-rmse:0.37418
# [103]	validation_0-rmse:0.13223	validation_1-rmse:0.37412
# [104]	validation_0-rmse:0.13202	validation_1-rmse:0.37404
# [105]	validation_0-rmse:0.13179	validation_1-rmse:0.37403
# [106]	validation_0-rmse:0.13172	validation_1-rmse:0.37399
# [107]	validation_0-rmse:0.13151	validation_1-rmse:0.37387
# [108]	validation_0-rmse:0.13128	validation_1-rmse:0.37386
# [109]	validation_0-rmse:0.13115	validation_1-rmse:0.37370
# [110]	validation_0-rmse:0.13070	validation_1-rmse:0.37361
# [111]	validation_0-rmse:0.13050	validation_1-rmse:0.37308
# [112]	validation_0-rmse:0.13037	validation_1-rmse:0.37285
# [113]	validation_0-rmse:0.12989	validation_1-rmse:0.37272
# [114]	validation_0-rmse:0.12978	validation_1-rmse:0.37255
# [115]	validation_0-rmse:0.12953	validation_1-rmse:0.37226
# [116]	validation_0-rmse:0.12939	validation_1-rmse:0.37227
# [117]	validation_0-rmse:0.12923	validation_1-rmse:0.37230
# [118]	validation_0-rmse:0.12901	validation_1-rmse:0.37224
# [119]	validation_0-rmse:0.12891	validation_1-rmse:0.37226
# [120]	validation_0-rmse:0.12882	validation_1-rmse:0.37221
# [121]	validation_0-rmse:0.12854	validation_1-rmse:0.37213
# [122]	validation_0-rmse:0.12839	validation_1-rmse:0.37206
# [123]	validation_0-rmse:0.12812	validation_1-rmse:0.37225
# [124]	validation_0-rmse:0.12798	validation_1-rmse:0.37172
# [125]	validation_0-rmse:0.12733	validation_1-rmse:0.37156
# [126]	validation_0-rmse:0.12719	validation_1-rmse:0.37139
# [127]	validation_0-rmse:0.12710	validation_1-rmse:0.37127
# [128]	validation_0-rmse:0.12702	validation_1-rmse:0.37120
# [129]	validation_0-rmse:0.12686	validation_1-rmse:0.37124
# [130]	validation_0-rmse:0.12657	validation_1-rmse:0.37116
# [131]	validation_0-rmse:0.12643	validation_1-rmse:0.37062
# [132]	validation_0-rmse:0.12640	validation_1-rmse:0.37061
# [133]	validation_0-rmse:0.12629	validation_1-rmse:0.37056
# [134]	validation_0-rmse:0.12582	validation_1-rmse:0.37041
# [135]	validation_0-rmse:0.12560	validation_1-rmse:0.37017
# [136]	validation_0-rmse:0.12543	validation_1-rmse:0.37012
# [137]	validation_0-rmse:0.12531	validation_1-rmse:0.37005
# [138]	validation_0-rmse:0.12500	validation_1-rmse:0.36993
# [139]	validation_0-rmse:0.12484	validation_1-rmse:0.36982
# [140]	validation_0-rmse:0.12470	validation_1-rmse:0.36984
# [141]	validation_0-rmse:0.12455	validation_1-rmse:0.36971
# [142]	validation_0-rmse:0.12443	validation_1-rmse:0.36972
# [143]	validation_0-rmse:0.12431	validation_1-rmse:0.36961
# [144]	validation_0-rmse:0.12419	validation_1-rmse:0.36953
# [145]	validation_0-rmse:0.12412	validation_1-rmse:0.36937
# [146]	validation_0-rmse:0.12388	validation_1-rmse:0.36934
# [147]	validation_0-rmse:0.12366	validation_1-rmse:0.36924
# [148]	validation_0-rmse:0.12354	validation_1-rmse:0.36929
# [149]	validation_0-rmse:0.12344	validation_1-rmse:0.36923
# [150]	validation_0-rmse:0.12335	validation_1-rmse:0.36922
# [151]	validation_0-rmse:0.12324	validation_1-rmse:0.36916
# [152]	validation_0-rmse:0.12310	validation_1-rmse:0.36911
# [153]	validation_0-rmse:0.12279	validation_1-rmse:0.36897
# [154]	validation_0-rmse:0.12254	validation_1-rmse:0.36895
# [155]	validation_0-rmse:0.12241	validation_1-rmse:0.36891
# [156]	validation_0-rmse:0.12217	validation_1-rmse:0.36878
# [157]	validation_0-rmse:0.12194	validation_1-rmse:0.36869
# [158]	validation_0-rmse:0.12181	validation_1-rmse:0.36870
# [159]	validation_0-rmse:0.12168	validation_1-rmse:0.36826
# [160]	validation_0-rmse:0.12159	validation_1-rmse:0.36814
# [161]	validation_0-rmse:0.12124	validation_1-rmse:0.36801
# [162]	validation_0-rmse:0.12119	validation_1-rmse:0.36803
# [163]	validation_0-rmse:0.12111	validation_1-rmse:0.36803
# [164]	validation_0-rmse:0.12107	validation_1-rmse:0.36803
# [165]	validation_0-rmse:0.12090	validation_1-rmse:0.36784
# [166]	validation_0-rmse:0.12072	validation_1-rmse:0.36779
# [167]	validation_0-rmse:0.12066	validation_1-rmse:0.36771
# [168]	validation_0-rmse:0.12061	validation_1-rmse:0.36771
# [169]	validation_0-rmse:0.12048	validation_1-rmse:0.36772
# [170]	validation_0-rmse:0.12022	validation_1-rmse:0.36762
# [171]	validation_0-rmse:0.12019	validation_1-rmse:0.36756
# [172]	validation_0-rmse:0.12006	validation_1-rmse:0.36753
# [173]	validation_0-rmse:0.12002	validation_1-rmse:0.36750
# [174]	validation_0-rmse:0.11998	validation_1-rmse:0.36746
# [175]	validation_0-rmse:0.11988	validation_1-rmse:0.36743
# [176]	validation_0-rmse:0.11952	validation_1-rmse:0.36727
# [177]	validation_0-rmse:0.11938	validation_1-rmse:0.36719
# [178]	validation_0-rmse:0.11917	validation_1-rmse:0.36711
# [179]	validation_0-rmse:0.11908	validation_1-rmse:0.36654
# [180]	validation_0-rmse:0.11893	validation_1-rmse:0.36649
# [181]	validation_0-rmse:0.11875	validation_1-rmse:0.36623
# [182]	validation_0-rmse:0.11858	validation_1-rmse:0.36616
# [183]	validation_0-rmse:0.11849	validation_1-rmse:0.36612
# [184]	validation_0-rmse:0.11838	validation_1-rmse:0.36609
# [185]	validation_0-rmse:0.11824	validation_1-rmse:0.36596
# [186]	validation_0-rmse:0.11809	validation_1-rmse:0.36592
# [187]	validation_0-rmse:0.11793	validation_1-rmse:0.36579
# [188]	validation_0-rmse:0.11786	validation_1-rmse:0.36579
# [189]	validation_0-rmse:0.11757	validation_1-rmse:0.36561
# [190]	validation_0-rmse:0.11740	validation_1-rmse:0.36566
# [191]	validation_0-rmse:0.11712	validation_1-rmse:0.36556
# [192]	validation_0-rmse:0.11699	validation_1-rmse:0.36547
# [193]	validation_0-rmse:0.11694	validation_1-rmse:0.36550
# [194]	validation_0-rmse:0.11691	validation_1-rmse:0.36546
# [195]	validation_0-rmse:0.11675	validation_1-rmse:0.36528
# [196]	validation_0-rmse:0.11672	validation_1-rmse:0.36528
# [197]	validation_0-rmse:0.11669	validation_1-rmse:0.36527
# [198]	validation_0-rmse:0.11663	validation_1-rmse:0.36523
# [199]	validation_0-rmse:0.11642	validation_1-rmse:0.36520
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.2, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=200, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = boosting.predict(X_val_encoded)
print('R^2', r2_score(y_val, y_pred))
# Out:
# R^2 0.5581005594984417

# %% [markdown]
# ## 평가 지표 계산 후 베이스 라인과 비교

# %%
y_pred = [y_train.mean()] * len(y_train)

print('Baseline MAE:', round(mean_absolute_error(y_train, y_pred), 3))
# Out:
# Baseline MAE: 0.403

# %%
from sklearn.metrics import mean_absolute_error


print('Linear Regression Test MAE: ', round(mean_absolute_error(y_val, lm.predict(X_val)), 3))

print('Random Forest Regression Test MAE: ', round(mean_absolute_error(y_val, rm.predict(X_val)), 3))

print('Gradiant Boost Regression Test MAE: ', round(mean_absolute_error(y_val, y_pred), 3))
# Out:
# Linear Regression Test MAE:  0.395
# Random Forest Regression Test MAE:  0.313
# Gradiant Boost Regression Test MAE:  0.325

# %%
lm_y_pred = lm.predict(X_val)

errors = abs(lm_y_pred - y_val)
mape = 100 * (errors /y_train)
accuracy = 100 - np.mean(mape)
print('Linear Regressoion Model Prediction Accuracy:', accuracy,'%.')
# Out:
# Linear Regressoion Model Prediction Accuracy: 98.0292111797503 %.

# %%
rf_y_pred = rm.predict(X_val)

errors = abs(rf_y_pred - y_val)
mape = 100 * (errors /y_train)
accuracy = 100 - np.mean(mape)
print('Random Frest Regressoion Model Prediction Accuracy:', round(accuracy, 2),'%.')
# Out:
# Random Frest Regressoion Model Prediction Accuracy: 98.44 %.

# %%
y_pred = boosting.predict(X_val_encoded)

errors = abs(y_pred - y_val)
mape = 100 * (errors /y_train)
accuracy = 100 - np.mean(mape)
print('Gradiant Boost Regression Model Prediction Accuracy:', round(accuracy, 2),'%.')
# Out:
# Gradiant Boost Regression Model Prediction Accuracy: 98.38 %.

# %% [markdown]
# Random Frest Regressoion 으로 모델을 만들었을 때의 정확도가  98.44 %가 됩니다. 3가지 회귀 모델 중 가장 높은 성능을 가지고 있다.

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# RandomForestRegressor model로 Radom Search CV best 파라미터 찾기

# %%
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV


pipe = make_pipeline(
    TargetEncoder(), 
    SimpleImputer(strategy='most_frequent'), 
    RandomForestRegressor(random_state=2)
)

dists = {
    'targetencoder__smoothing': [2.,20.,50.,60.,100.], # int로 넣으면 error(bug)
    'targetencoder__min_samples_leaf': randint(1, 10),     
    'randomforestregressor__n_estimators': randint(25, 100), 
    'randomforestregressor__max_depth': [5, 10, 15, 20, None], 
    'randomforestregressor__max_features': uniform(0, 1) # max_features
}

clf = RandomizedSearchCV(
    pipe, 
    param_distributions=dists, 
    n_iter=5, 
    cv=3, 
    scoring='neg_mean_absolute_error',  
    verbose=1,
    n_jobs=-1
)

# %%
clf.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  6.0min finished

# %%
print('최적 하이퍼파라미터: ', clf.best_params_)
print('교차 검증 된 평균 점수: ', -clf.best_score_)

# %%
pipe = clf.best_estimator_

# %%
y_test_best_pred = pipe.predict(X_test)
print('Random Forest Regression Test MAE: ', round(mean_absolute_error(y_test, y_test_best_pred), 3))
print('Test R^2', r2_score(y_test, y_test_best_pred))
# Out:
# Random Forest Regression Test MAE:  0.33
# Test R^2 0.5499397297571766

# %%
y_test_pred = rm.predict(X_test)
print('Random Forest Regression Test MAE: ', round(mean_absolute_error(y_test, y_test_pred), 3))
print('Test R^2', r2_score(y_test, y_test_pred))
# Out:
# Random Forest Regression Test MAE:  0.313
# Test R^2 0.5990404656036723

# %% [markdown]
# 최적의 하이퍼파라미터를 구했지만 H/W적인 문제로 시간이 오래걸려 많이 테스트해보지 못했다. RandomForest 0.5990의 값이 더 잘 나왔습니다.

# %% [markdown]
# ## Croos Validation 을 통해 일반화될 가능성 체크

# %%
from sklearn.model_selection import validation_curve

depth = range(1, 15, 2)

ts, vs = validation_curve(
    pipe, X_train, y_train
    , param_name='randomforestregressor__max_depth'
    , param_range=depth, scoring='neg_mean_absolute_error'
    , cv=3
    , n_jobs=-1
)

# %%
train_scores_mean = np.mean(-ts, axis=1)
validation_scores_mean = np.mean(-vs, axis=1)

fig, ax = plt.subplots()

# 훈련세트 검증곡선
ax.plot(depth, train_scores_mean, label='training error')

# 검증세트 검증곡선
ax.plot(depth, validation_scores_mean, label='validation error')

# 이상적인 max_depth
ax.vlines(5,0, train_scores_mean.max(), color='blue')

# 그래프 셋팅
ax.set(title='Validation Curve'
      , xlabel='Model Complexity(max_depth)', ylabel='MAE')
ax.legend()
fig.dpi = 100

# %% [markdown]
# ## Permutaition 을 통한 Feature 선택

# %%
pipe
# Out:
# Pipeline(steps=[('targetencoder',
#                  TargetEncoder(cols=['SGG_NM'], min_samples_leaf=3,
#                                smoothing=60.0)),
#                 ('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=20,
#                                        max_features=0.3647391876981543,
#                                        n_estimators=45, random_state=2))])

# %%
model_rf = pipe['randomforestregressor']
ecd = pipe['targetencoder']

# %%
pipe.named_steps
# Out:
# {'targetencoder': TargetEncoder(cols=['SGG_NM'], min_samples_leaf=3, smoothing=60.0),
#  'simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'randomforestregressor': RandomForestRegressor(max_depth=20, max_features=0.3647391876981543,
#                        n_estimators=45, random_state=2)}

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('preprocessing', make_pipeline(TargetEncoder(cols=['SGG_NM'], min_samples_leaf=4, smoothing=50.0), SimpleImputer(strategy='most_frequent'))),
    ('rf', RandomForestRegressor(max_depth=20, max_features=0.5366197983107657,
                       n_estimators=33, random_state=2, n_jobs=-1)) 
])

# %%
pipe.fit(X_train, y_train)
print('검증 정확도: ', pipe.score(X_val, y_val))
# Out:
# 검증 정확도:  0.5867701140757624

# %%
pipe.named_steps
# Out:
# {'preprocessing': Pipeline(steps=[('targetencoder',
#                   TargetEncoder(cols=['SGG_NM'], min_samples_leaf=4,
#                                 smoothing=50.0)),
#                  ('simpleimputer', SimpleImputer(strategy='most_frequent'))]),
#  'rf': RandomForestRegressor(max_depth=20, max_features=0.5366197983107657,
#                        n_estimators=33, n_jobs=-1, random_state=2)}

# %%
import eli5
from eli5.sklearn import PermutationImportance

# permuter 정의
permuter = PermutationImportance(
    pipe.named_steps['rf'], # model
    scoring='neg_mean_absolute_error', # metric
    n_iter=5, # 다른 random seed를 사용하여 5번 반복
    random_state=2
)


# permuter 계산은 preprocessing 된 X_val을 사용합니다.
X_val_transformed = pipe.named_steps['preprocessing'].transform(X_val)

# 실제로 fit 의미보다는 스코어를 다시 계산하는 작업입니다
permuter.fit(X_val_transformed, y_val);

# %%
eli5.show_weights(
    permuter, 
    top=None, # top n 지정 가능, None 일 경우 모든 특성 
    feature_names=X_val.columns.tolist() # list 형식으로 넣어야 합니다
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1584
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BLDG_AREA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1233
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SGG_NM
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0839
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BUILD_YEAR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0525
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BJDONG10_CD
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0084
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 YEON_AREA
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FLR_INFO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ACC_YEAR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 OBJ_SEQNO
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# 특성 중요도를 보면 법정동코드, 건물면적, 건축년도 등이 모델 성능과 관련이 있는 특성들로 보입니다. 전체 특성이 얼마 되지 않아 삭제를 하거나 하지는 않겠습니다.

# %% [markdown]
# **건물면적, 시군이름, 건축년도, 법정동코드 순으로 관련 있다는 것은 신축건물이면서, 지역별로 아파트의 가격에 영향을 많이 미친다고 볼 수 있습니다.** 이후에 모델을 만들고 모델 동작 방식을 보면서 중요성을 한번 더 짚어보겠습니다.

# %% [markdown]
# # 최종 모델 적용

# %% [markdown]
# Baseline MAE: 0.403 이었습니다. 모델을 적용한 결과 MAE가 낮아 지므로 성능이 더 좋은것을 볼 수있습니다.

# %%
print('Validation MAE:', mean_absolute_error(y_val, pipe.predict(X_val)))
# Out:
# Validation MAE: 0.31728359756263774

# %% [markdown]
# RadomSearchCV로 구한 최적의  하이퍼파라미터를 적용한 clf 모델을 사용해서 test 데이터를 예측

# %%
print('Validation MAE:', mean_absolute_error(y_test, pipe.predict(X_test)))

y_test_pred = pipe.predict(X_test)
print('Test R^2', r2_score(y_test, y_test_pred))
# Out:
# Validation MAE: 0.3172835975626377
# Test R^2 0.5867701140757626

# %% [markdown]
# # 머신러닝 모델 해석
#
# 1)모델이 관측치를 예측하기 위해서 어떤 특성을 활용했나요?
#
# 2) 어떤 특성이 있다면 모델의 예측에 도움이 될까요? 해당 특성은 어떻게 구할 수 있을까요?

# %% [markdown]
# ##  SHAP, PDP 등을 통해서 모델이 관측치를 어떤 특성을 활용했거나, 어떤 특성이 타겟에 영향을 끼쳤는지 등을 해석

# %% [markdown]
# ### PDP를 통한 모델 Interpreting

# %%
from pdpbox.pdp import pdp_isolate, pdp_plot

feature = 'BLDG_AREA'

isolated = pdp_isolate(
    model=pipe,
    dataset=X_val,
    model_features = X_val.columns,
    feature = feature
)

# %%
feature = 'BLDG_AREA'

pdp_plot(isolated, feature_name=feature);

# %% [markdown]
# ### SHAP를 통한 모델 Interpreting

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('targetencoder',
#                                   TargetEncoder(cols=['SGG_NM'],
#                                                 min_samples_leaf=4,
#                                                 smoothing=50.0)),
#                                  ('simpleimputer',
#                                   SimpleImputer(strategy='most_frequent'))])),
#                 ('rf',
#                  RandomForestRegressor(max_depth=20,
#                                        max_features=0.5366197983107657,
#                                        n_estimators=33, n_jobs=-1,
#                                        random_state=2))])

# %%
enc = pipe['preprocessing']['targetencoder']

# %%
X_target_encoded = enc.fit_transform(X_val, y_val)
row = X_target_encoded.iloc[:100]
row
# Out:
#        SGG_NM  BJDONG10_CD  ACC_YEAR  OBJ_SEQNO  BLDG_AREA  FLR_INFO  \
# 0   20.087829   1130510200      2021          1      49.94       7.0
# 1   20.406312   1141011100      2021          1      84.96      10.0
# 2   20.406312   1141011100      2021          1      59.94      11.0
# 3   20.406312   1141012000      2021          1      59.98       4.0
# 4   20.406312   1141010900      2021          1      84.87      17.0
# ..        ...          ...       ...        ...        ...       ...
# 95  19.934357   1154510300      2021          1     114.84      11.0
# 96  20.406312   1141012000      2021          1      84.97      18.0
# 97  20.406312   1141011000      2021          1      59.96       3.0
# 98  19.934357   1154510300      2021          1      84.99      12.0
# 99  20.406312   1141011100      2021          1      84.12       8.0
#
#     BUILD_YEAR  YEON_AREA
# 0       1991.0     349.58
# 1       2001.0     849.60
# 2       2002.0     659.34
# 3       2015.0     239.92
# 4       1998.0    1442.79
# ..         ...        ...
# 95      2004.0    1263.24
# 96      2015.0    1529.46
# 97      1999.0     179.88
# 98      2000.0    1019.88
# 99      2015.0     672.96
#
# [100 rows x 8 columns]

# %%
row_one = X_target_encoded.iloc[[1]]  # 중첩 brackets을 사용하면 결과물이 DataFrame입니다
row_one
# Out:
#       SGG_NM  BJDONG10_CD  ACC_YEAR  OBJ_SEQNO  BLDG_AREA  FLR_INFO  \
# 1  20.406312   1141011100      2021          1      84.96      10.0
#
#    BUILD_YEAR  YEON_AREA
# 1      2001.0      849.6

# %%
# 실제 집값
y_test.iloc[[1]]  # 서대문구	1141011100	홍제동
# Out:
# 1    20.560747
# Name: OBJ_AMT, dtype: float64

# %%
best_pipe = clf.best_estimator_
best_pipe
# Out:
# Pipeline(steps=[('targetencoder',
#                  TargetEncoder(cols=['SGG_NM'], min_samples_leaf=3,
#                                smoothing=60.0)),
#                 ('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=20,
#                                        max_features=0.3647391876981543,
#                                        n_estimators=45, random_state=2))])

# %%
# 모델 예측값
best_pipe.predict(row_one)
# Out:
# array([20.21498103])

# %%
import shap

shap.initjs()

explainer = shap.TreeExplainer(best_pipe['randomforestregressor'])
shap_values = explainer.shap_values(row_one)


shap.force_plot(
    base_value=explainer.expected_value, 
    shap_values=shap_values,
    features=row_one
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iGH0621IIN2GHLMERL40X'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 19.896526483263898, "outValue": 20.56568808724128, "link": "identity", "featureNames": ["SGG_NM", "BJDONG10_CD", "ACC_YEAR", "OBJ_SEQNO", "BLDG_AREA", "FLR_INFO", "BUILD_YEAR", "YEON_AREA"], "features": {"0": {"effect": 0.35968740510827824, "value": 20.406312218688768}, "1": {"effect": -0.025242366272505187, "value": 1141011100.0}, "2": {"effect": 0.25885031095935623, "value": 2021.0}, "3": {"effect": 0.00016288096119500387, "value": 1.0}, "4": {"effect": 0.11948517217508428, "value": 84.96}, "5": {"effect": -0.0031784365303601176, "value": 10.0}, "6": {"effect": -0.0784260137200494, "value": 2001.0}, "7": {"effect": 0.037822651296384194, "value": 849.5999999999999}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iGH0621IIN2GHLMERL40X')
#   );
# </script>

# %%
np.exp(20.57) # 모델로 예측한 집 가격
# Out:
# 857901629.545542

# %% [markdown]
# 서대문구 홍제동의 집값을 예측한 결과 857901629원 으로 서울시 지역 서대문구, 거래 신고년도, 건축 면적이 특성이 집값을 증가시켰다.

# %%
row_gangnam = X_target_encoded[X_target_encoded.BJDONG10_CD == 1168011200].iloc[[1]]


shap.initjs()

explainer = shap.TreeExplainer(best_pipe['randomforestregressor'])
shap_values = explainer.shap_values(row_gangnam)


shap.force_plot(
    base_value=explainer.expected_value, 
    shap_values=shap_values,
    features=row_gangnam
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iLC5SWSD7Z3A7JD4OHCTH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 19.896526483263898, "outValue": 20.61807666348856, "link": "identity", "featureNames": ["SGG_NM", "BJDONG10_CD", "ACC_YEAR", "OBJ_SEQNO", "BLDG_AREA", "FLR_INFO", "BUILD_YEAR", "YEON_AREA"], "features": {"0": {"effect": 0.29514575521754544, "value": 20.962507078812166}, "1": {"effect": 0.18198194339684107, "value": 1168011200.0}, "2": {"effect": 0.2876160158806327, "value": 2021.0}, "3": {"effect": 0.0011735433384168171, "value": 1.0}, "4": {"effect": -0.07551336591706004, "value": 59.96}, "5": {"effect": 0.001423476379058644, "value": 7.0}, "6": {"effect": 0.062177719247738024, "value": 2014.0}, "7": {"effect": -0.0324549073185124, "value": 419.72}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLC5SWSD7Z3A7JD4OHCTH')
#   );
# </script>

# %%
np.exp(20.62)
# Out:
# 901887186.6751202

# %% [markdown]
# 강남구의 집값을 예측한 결과 901887186원 으로 서울시 지역 강남구, 거래 신고년도, 건축 면적이 특성이 집값을 증가시켰다.

# %% [markdown]
# SGG_NM, ACC_YEAR, BULDG_AREA 가 집값을 예측하는 중요한 요소이다. 서울시 아파트는 지역에따라(시군) 가장 영향을 많이 미친다.

# %%
X_target_encoded = enc.fit_transform(X_val, y_val)
row = X_target_encoded.iloc[:20]
row
# Out:
#        SGG_NM  BJDONG10_CD  ACC_YEAR  OBJ_SEQNO  BLDG_AREA  FLR_INFO  \
# 0   20.087829   1130510200      2021          1      49.94       7.0
# 1   20.406312   1141011100      2021          1      84.96      10.0
# 2   20.406312   1141011100      2021          1      59.94      11.0
# 3   20.406312   1141012000      2021          1      59.98       4.0
# 4   20.406312   1141010900      2021          1      84.87      17.0
# 5   20.406312   1141011700      2021          1      63.60       5.0
# 6   20.406312   1141011100      2021          1      84.79       8.0
# 7   20.406312   1141011100      2021          1      84.95       6.0
# 8   20.406312   1141011700      2021          1      77.41       6.0
# 9   19.934357   1154510300      2021          1      49.75      12.0
# 10  20.406312   1141011100      2021          1      84.78      16.0
# 11  19.934357   1154510200      2021          1      89.46       6.0
# 12  20.406312   1141012000      2021          1      59.59      16.0
# 13  20.406312   1141012000      2021          1      59.59      16.0
# 14  20.406312   1141011100      2021          1      84.78      15.0
# 15  20.406312   1141011000      2021          1      84.82       9.0
# 16  20.406312   1141011700      2021          1      84.95       5.0
# 17  19.934357   1154510300      2021          1      59.34       8.0
# 18  20.406312   1141011800      2021          1      99.35       2.0
# 19  19.934357   1154510300      2021          1      84.97      11.0
#
#     BUILD_YEAR  YEON_AREA
# 0       1991.0     349.58
# 1       2001.0     849.60
# 2       2002.0     659.34
# 3       2015.0     239.92
# 4       1998.0    1442.79
# 5       1978.0     318.00
# 6       2016.0     678.32
# 7       2006.0     509.70
# 8       2004.0     464.46
# 9       1981.0     597.00
# 10      1994.0    1356.48
# 11      1991.0     536.76
# 12      2000.0     953.44
# 13      2000.0     953.44
# 14      1994.0    1271.70
# 15      2018.0     763.38
# 16      2001.0     424.75
# 17      2004.0     474.72
# 18      2003.0     198.70
# 19      2004.0     934.67

# %%
row = X_target_encoded.iloc[:50]
shap_values = explainer.shap_values(row)
shap.summary_plot(shap_values, row)

# %% [markdown]
# summary plot에서 특성값과 예측에 미치는 영향 사이의 관계 지표를 볼 수 있다. 서울시의 시군이름은 집값의 가장 긍정적인 역할을 한다.
#
# 최종모델 점수
#
# Validation MAE: 0.3172835975626377
#
# Test R^2 0.5867701140757626
#
# 10년간의 데이터로 2020년 이후의 집 값을 꽤 잘 예측한 것으로 보입니다. 정부의 규제나 다른 외적인 요인들을 추가한다면 더 좋은 모델을 만들어 앞으로의 집값예측에 도움이 될 수 있는 자료가 될 것입니다.

# %% [markdown]
# 감사합니다.
